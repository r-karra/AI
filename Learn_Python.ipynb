# %% [markdown]
# <a href="https://colab.research.google.com/github/r-karra/AI/blob/main/Learn_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Learn Python with me using the Feynman technique
#
#
#
#
# 1. Choose a concept to learn.
# 2. Teach it to yourself or someone else.
# 3. Return to the source material if you get stuck.
# 4. Simplify your explanations and create analogies.
